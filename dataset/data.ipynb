# %%
import pandas as pd
import numpy as np

# %%
# Load a CSV file as a data frame (df) using pandas
# Parameters: filepath_or_buffer; use separator: default "," 
df = pd.read_csv('cars2017.csv', sep=',')

# %%
print(f'max engines: {df["EngineCylinders"].max()}')
print(f'min engines: {df["EngineCylinders"].min()}')
print(df['EngineCylinders'].value_counts())


# print(f'max Collaborative_Streams_in_millions: {df["Collaborative_Streams_in_millions"].max()}')
# print(f'min Collaborative_Streams_in_millions: {df["Collaborative_Streams_in_millions"].min()}')

# print(f'max no_of_Collaborative_Streams: {df["no_of_Collaborative_Streams"].max()}')
# print(f'min no_of_Collaborative_Streams: {df["no_of_Collaborative_Streams"].min()}')
# Out:
# max engines: 12
# min engines: 0
# EngineCylinders
# 4     52
# 6     39
# 8     30
# 0     10
# 12     7
# 3      4
# 10     3
# 2      1
# Name: count, dtype: int64
